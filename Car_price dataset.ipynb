# %%
# import the library
import numpy as np
import pandas as pd

# %%
#importing the visualisation library
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in the dataset
car= pd.read_csv('car data.csv')
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
#Checking the dataset information 
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
# drop the duplicate
car.drop_duplicates()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
sns.scatterplot(x='Selling_Price',y='Year',data=car,hue='Fuel_Type')
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Year'>

# %%
sns.scatterplot(x='Present_Price',y='Selling_Price',data=car,hue='Fuel_Type')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(car['Selling_Price'])
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Count'>

# %%
# Encoding dataset section in order to change the categorical value to numeric
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
# selecting the column to encode
car['Selling_type_n'] = le.fit_transform(car['Selling_type'])
car['Fuel_Type_n'] = le.fit_transform(car['Fuel_Type'])
car['Transmission_n'] = le.fit_transform(car['Transmission'])

# %%
# call the data set
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner  Selling_type_n  Fuel_Type_n  \
# ...

# %%
# drop the colum categorical after the encoding   
car=car.drop(columns=['Fuel_Type','Selling_type','Transmission','Car_Name'])

# %%
# call the dataset
car
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms  Owner  Selling_type_n  \
# 0    2014           3.35           5.59       27000      0               0
# 1    2013           4.75           9.54       43000      0               0
# 2    2017           7.25           9.85        6900      0               0
# 3    2011           2.85           4.15        5200      0               0
# 4    2014           4.60           6.87       42450      0               0
# ..    ...            ...            ...         ...    ...             ...
# 296  2016           9.50          11.60       33988      0               0
# 297  2015           4.00           5.90       60000      0               0
# 298  2009           3.35          11.00       87934      0               0
# 299  2017          11.50          12.50        9000      0               0
# 300  2016           5.30           5.90        5464      0               0
#
#      Fuel_Type_n  Transmission_n
# 0              2               1
# ...

# %%
# checking for missing value
car.isnull().sum()
# Out:
# Year              0
# Selling_Price     0
# Present_Price     0
# Driven_kms        0
# Owner             0
# Selling_type_n    0
# Fuel_Type_n       0
# Transmission_n    0
# dtype: int64

# %%
# dropping the target variable and remains feature variable
X=car.drop(columns='Selling_Price')
X
# Out:
#      Year  Present_Price  Driven_kms  Owner  Selling_type_n  Fuel_Type_n  \
# 0    2014           5.59       27000      0               0            2
# 1    2013           9.54       43000      0               0            1
# 2    2017           9.85        6900      0               0            2
# 3    2011           4.15        5200      0               0            2
# 4    2014           6.87       42450      0               0            1
# ..    ...            ...         ...    ...             ...          ...
# 296  2016          11.60       33988      0               0            1
# 297  2015           5.90       60000      0               0            2
# 298  2009          11.00       87934      0               0            2
# 299  2017          12.50        9000      0               0            1
# 300  2016           5.90        5464      0               0            2
#
#      Transmission_n
# 0                 1
# 1                 1
# 2                 1
# ...

# %%
#selecting my target variable
y=car['Selling_Price']
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
#importing library of training and test
from sklearn.model_selection import train_test_split

# %%
## splitting  data into training and testing set section
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.2 ,random_state=42)

# %%
#initialising the model and train in Randonregressor
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()

# %%
# initiallising the model
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
# make prediction on the test 
y_predict=model.predict(X_test)

# %%
y_predict
# Out:
# array([ 0.45  ,  9.6078,  4.6385,  0.2466, 11.3129,  6.48  ,  1.1025,
#         0.6199,  0.4554,  6.349 ,  8.425 ,  1.0688,  8.8263,  0.5353,
#         5.0765,  2.847 ,  1.2548, 13.3586,  0.533 ,  1.4148,  0.3988,
#         7.6675,  5.399 ,  3.212 ,  0.4581,  4.2635,  4.54  ,  3.9615,
#         1.1848,  1.1166,  0.4966,  8.5071,  0.4244,  3.7655,  6.739 ,
#         4.953 ,  9.689 , 10.3417,  2.7895, 10.4382,  6.7575,  6.4185,
#         5.028 ,  0.4303,  6.1715,  0.442 ,  8.2965, 13.066 ,  3.0085,
#         4.0265,  5.707 ,  1.238 , 14.9468, 16.2121,  6.493 , 11.0706,
#         5.1375,  8.0603,  4.183 ,  6.3815,  0.2662,  0.3147,  0.7043,
#         0.3868,  4.868 ,  1.1512, 14.9131, 15.0049,  5.8695,  0.3962,
#         4.0625,  4.666 ,  5.9725,  4.9505,  2.963 ,  1.1229,  0.6743,
#        13.3674,  0.3776,  8.9896,  5.236 ,  4.3015,  7.9088, 15.8596,
#         2.89  ,  0.4966,  1.3299,  4.4205,  0.4181, 14.8843,  1.1007,
# ...

# %%
#model evalutation  sections
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# np.float64(1.2223680497925307)

# %%
r2_score(y_test,y_predict)
# Out:
# 0.7140943004832063
